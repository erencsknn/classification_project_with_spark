# %% [markdown]
# <a href="https://colab.research.google.com/github/erencsknn/classification_project_with_spark/blob/main/spark_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pyspark import SparkContext

# %%
from pyspark.sql.types import *
from pyspark.sql.functions import *
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.feature import VectorAssembler

# %%
csv = spark.read.csv("flights.csv",inferSchema=True, header=True)
csv.show()
# Out:
# +----------+---------+-------+---------------+-------------+--------+--------+
# |DayofMonth|DayOfWeek|Carrier|OriginAirportID|DestAirportID|DepDelay|ArrDelay|
# +----------+---------+-------+---------------+-------------+--------+--------+
# |        19|        5|     DL|          11433|        13303|      -3|       1|
# |        19|        5|     DL|          14869|        12478|       0|      -8|
# |        19|        5|     DL|          14057|        14869|      -4|     -15|
# |        19|        5|     DL|          15016|        11433|      28|      24|
# |        19|        5|     DL|          11193|        12892|      -6|     -11|
# |        19|        5|     DL|          10397|        15016|      -1|     -19|
# |        19|        5|     DL|          15016|        10397|       0|      -1|
# |        19|        5|     DL|          10397|        14869|      15|      24|
# |        19|        5|     DL|          10397|        10423|      33|      34|
# |        19|        5|     DL|          11278|        10397|     323|     322|
# |        19|        5|     DL|          14107|        13487|      -7|     -13|
# |        19|        5|     DL|          11433|        11298|      22|      41|
# |        19|        5|     DL|          11298|        11433|      40|      20|
# |        19|        5|     DL|          11433|        12892|      -2|      -7|
# |        19|        5|     DL|          10397|        12451|      71|      75|
# |        19|        5|     DL|          12451|        10397|      75|      57|
# |        19|        5|     DL|          12953|        10397|      -1|      10|
# |        19|        5|     DL|          11433|        12953|      -3|     -10|
# |        19|        5|     DL|          10397|        14771|      31|      38|
# |        19|        5|     DL|          13204|        10397|       8|      25|
# +----------+---------+-------+---------------+-------------+--------+--------+
# only showing top 20 rows

# %%
data = csv.select("DayofMonth", "DayOfWeek", "OriginAirportID", "DestAirportID",
"DepDelay", ((col("ArrDelay") > 15).cast("int").alias("Late")))
data.show()
# Out:
# +----------+---------+---------------+-------------+--------+----+
# |DayofMonth|DayOfWeek|OriginAirportID|DestAirportID|DepDelay|Late|
# +----------+---------+---------------+-------------+--------+----+
# |        19|        5|          11433|        13303|      -3|   0|
# |        19|        5|          14869|        12478|       0|   0|
# |        19|        5|          14057|        14869|      -4|   0|
# |        19|        5|          15016|        11433|      28|   1|
# |        19|        5|          11193|        12892|      -6|   0|
# |        19|        5|          10397|        15016|      -1|   0|
# |        19|        5|          15016|        10397|       0|   0|
# |        19|        5|          10397|        14869|      15|   1|
# |        19|        5|          10397|        10423|      33|   1|
# |        19|        5|          11278|        10397|     323|   1|
# |        19|        5|          14107|        13487|      -7|   0|
# |        19|        5|          11433|        11298|      22|   1|
# |        19|        5|          11298|        11433|      40|   1|
# |        19|        5|          11433|        12892|      -2|   0|
# |        19|        5|          10397|        12451|      71|   1|
# |        19|        5|          12451|        10397|      75|   1|
# |        19|        5|          12953|        10397|      -1|   0|
# |        19|        5|          11433|        12953|      -3|   0|
# |        19|        5|          10397|        14771|      31|   1|
# |        19|        5|          13204|        10397|       8|   1|
# +----------+---------+---------------+-------------+--------+----+
# only showing top 20 rows

# %%
type(data.columns[:-1])
# Out:
# list

# %%
splits = data.randomSplit([0.7, 0.3])
train = splits[0]
test = splits[1]
train_rows = train.count()
test_rows = test.count()
print("Training Rows:", train_rows, " Testing Rows:", test_rows)
# Out:
# Training Rows: 604462  Testing Rows: 260064

# %%
assembler = VectorAssembler(inputCols=data.columns[:-1],outputCol="features")
training = assembler.transform(train).select(col("features"),col("Late").alias("label"))
training.show()
# Out:
# +--------------------+-----+
# |            features|label|
# +--------------------+-----+
# |[1.0,1.0,10140.0,...|    0|
# |[1.0,1.0,10140.0,...|    0|
# |[1.0,1.0,10140.0,...|    0|
# |[1.0,1.0,10140.0,...|    0|
# |[1.0,1.0,10140.0,...|    0|
# |[1.0,1.0,10140.0,...|    0|
# |[1.0,1.0,10140.0,...|    1|
# |[1.0,1.0,10140.0,...|    0|
# |[1.0,1.0,10140.0,...|    0|
# |[1.0,1.0,10140.0,...|    0|
# |[1.0,1.0,10140.0,...|    0|
# |[1.0,1.0,10140.0,...|    0|
# |[1.0,1.0,10140.0,...|    0|
# |[1.0,1.0,10140.0,...|    0|
# |[1.0,1.0,10140.0,...|    1|
# |[1.0,1.0,10140.0,...|    0|
# |[1.0,1.0,10140.0,...|    0|
# |[1.0,1.0,10140.0,...|    1|
# |[1.0,1.0,10140.0,...|    0|
# |[1.0,1.0,10140.0,...|    0|
# +--------------------+-----+
# only showing top 20 rows

# %%
lr = LogisticRegression(labelCol="label",featuresCol="features")
model = lr.fit(training)

# %%
testing = assembler.transform(test).select(col("features"),col("Late").alias("TrueLabel"))
testing.show()
# Out:
# +--------------------+---------+
# |            features|TrueLabel|
# +--------------------+---------+
# |[1.0,1.0,10140.0,...|        0|
# |[1.0,1.0,10140.0,...|        0|
# |[1.0,1.0,10140.0,...|        1|
# |[1.0,1.0,10140.0,...|        1|
# |[1.0,1.0,10140.0,...|        0|
# |[1.0,1.0,10140.0,...|        0|
# |[1.0,1.0,10140.0,...|        0|
# |[1.0,1.0,10140.0,...|        0|
# |[1.0,1.0,10140.0,...|        0|
# |[1.0,1.0,10140.0,...|        0|
# |[1.0,1.0,10140.0,...|        0|
# |[1.0,1.0,10140.0,...|        0|
# |[1.0,1.0,10140.0,...|        0|
# |[1.0,1.0,10140.0,...|        0|
# |[1.0,1.0,10140.0,...|        0|
# |[1.0,1.0,10140.0,...|        1|
# |[1.0,1.0,10140.0,...|        0|
# |[1.0,1.0,10140.0,...|        0|
# |[1.0,1.0,10140.0,...|        0|
# |[1.0,1.0,10140.0,...|        0|
# +--------------------+---------+
# only showing top 20 rows

# %%
prediction = model.transform(testing)
predicted = prediction.select("features","prediction","probability","TrueLabel")
predicted.show(100,truncate=False)
# Out:
# +-------------------------------+----------+------------------------------------------+---------+
# |features                       |prediction|probability                               |TrueLabel|
# +-------------------------------+----------+------------------------------------------+---------+
# |[1.0,1.0,10397.0,11298.0,4.0]  |0.0       |[0.9027269253981623,0.09727307460183765]  |0        |
# |[1.0,1.0,10397.0,11298.0,6.0]  |0.0       |[0.8761670555474255,0.12383294445257453]  |0        |
# |[1.0,1.0,10397.0,11433.0,-4.0] |0.0       |[0.9650973440753281,0.0349026559246719]   |0        |
# |[1.0,1.0,10397.0,11433.0,11.0] |0.0       |[0.7833178534981534,0.21668214650184658]  |0        |
# |[1.0,1.0,10397.0,11618.0,-3.0] |0.0       |[0.9605764111543174,0.039423588845682644] |0        |
# |[1.0,1.0,10397.0,11618.0,-1.0] |0.0       |[0.948918216013952,0.05108178398604801]   |0        |
# |[1.0,1.0,10397.0,11618.0,4.0]  |0.0       |[0.9041064447488686,0.09589355525113141]  |0        |
# |[1.0,1.0,10397.0,11618.0,7.0]  |0.0       |[0.8625693973263243,0.13743060267367568]  |0        |
# |[1.0,1.0,10397.0,11618.0,69.0] |1.0       |[0.0013960463868196251,0.9986039536131803]|1        |
# |[1.0,1.0,10397.0,11618.0,69.0] |1.0       |[0.0013960463868196251,0.9986039536131803]|1        |
# |[1.0,1.0,10397.0,11697.0,-2.0] |0.0       |[0.9552736543319469,0.044726345668053114] |0        |
# |[1.0,1.0,10397.0,11697.0,1.0]  |0.0       |[0.9342892368609441,0.06571076313905588]  |0        |
# |[1.0,1.0,10397.0,11697.0,3.0]  |0.0       |[0.9155409891293618,0.08445901087063823]  |0        |
# |[1.0,1.0,10397.0,11697.0,5.0]  |0.0       |[0.89206157775491,0.10793842224508998]    |0        |
# |[1.0,1.0,10397.0,11697.0,8.0]  |0.0       |[0.8461947656596136,0.1538052343403864]   |0        |
# |[1.0,1.0,10397.0,11697.0,62.0] |1.0       |[0.003613890493846245,0.9963861095061538] |1        |
# |[1.0,1.0,10397.0,12173.0,-4.0] |0.0       |[0.966308179330952,0.03369182066904797]   |0        |
# |[1.0,1.0,10397.0,12191.0,-5.0] |0.0       |[0.9704809030423983,0.029519096957601687] |0        |
# |[1.0,1.0,10397.0,12191.0,-5.0] |0.0       |[0.9704809030423983,0.029519096957601687] |0        |
# |[1.0,1.0,10397.0,12191.0,-3.0] |0.0       |[0.9616346461033796,0.038365353896620435] |0        |
# +-------------------------------+----------+------------------------------------------+---------+
# only showing top 100 rows

# %%
tp = float(predicted.filter("prediction == 1.0 AND truelabel == 1").count())
fp = float(predicted.filter("prediction == 1.0 AND truelabel == 0").count())
tn = float(predicted.filter("prediction == 0.0 AND truelabel == 0").count())
fn = float(predicted.filter("prediction == 0.0 AND truelabel == 1").count())
metrics = spark.createDataFrame([
("TP", tp),
("FP", fp),
("TN", tn),
("FN", fn),
("Precision", tp / (tp + fp)),
("Recall", tp / (tp + fn))],["metric", "value"])
metrics.show()
# Out:
# +---------+------------------+
# |   metric|             value|
# +---------+------------------+
# |       TP|           37279.0|
# |       FP|            4225.0|
# |       TN|          203226.0|
# |       FN|           15334.0|
# |Precision|0.8982025828835775|
# |   Recall|0.7085511185448463|
# +---------+------------------+
